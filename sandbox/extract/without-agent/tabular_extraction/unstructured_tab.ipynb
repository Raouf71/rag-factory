# %% [markdown]
# ## Unstructured Tab example (Toy Catalog)

# %% [markdown]
# Extract structured data from documents containing repeating entities like tables, lists, or catalogs.
#
# ---
# Config:
# * ``Schema alignment``:
#     * extraction_target= PER_TABLE_ROW
#         - ****Clear structure****: The document has explicit table formatting with rows and columns
#         - ****Repeating entities****: Each row represents one hospital with consistent attributes
#         - ****Local information****: All data for each hospital (county, name, plans) is contained within its row
#     ⚠️
# * ``Model settings``:
#     * extraction_mode= PREMIUM (suitable for complex tables and information-dense documents )
#     * parse_model= "anthropic-sonnet-4.5"
#
# * ``Advanced options``:
#     * chunk_mode= PAGE
# ---

# %% [markdown]
# ### Choosing the Right Extraction Target
# | Extraction Target                   |                                                                                                                                                                                                                                                                                                Procedure/Result                                                                                                                                                                                                                                                                                                |
# |-------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | PER_DOC (Document-level extraction) | * ``Operation mode``: looks at the entire document's context. <br> * ``Issue(s)``: When extracting lists of entities, **LLM-based extraction has a critical failure mode** — it often only extracts the first few tens of entries from a long list.  This happens because LLMs have **limited attention spans for repetitive data**. <br> &rarr; ``Result``: complete extractions of long lists are not guaranteed.**                                                                                                                   |
# | PER_TABLE_ROW                       | * ``Operation mode``: It defines a schema for a single entity (e.g., one hospital, one product, one invoice line item), not the full document. <br> LlamaExtract automatically:<br>  * Detects the formatting patterns that distinguish individual entities (table rows, list items, section headers, etc.)<br> * Applies your schema to each identified entity<br> * Returns a **list[YourSchema]** with one object per entity<br> * ``Fixes``: It solves incomplete list extractions by processing each entity individually or in smaller batches.<br> &rarr; ``Result`` Ensuring exhaustive extraction of all entries regardless of list length. |

# %% [markdown]
# ### Provide api-keys manually

# %%
import os
from getpass import getpass

if "LLAMA_CLOUD_API_KEY" not in os.environ:
    os.environ["LLAMA_CLOUD_API_KEY"] = getpass("Enter your Llama Cloud API Key: ")
    os.environ["OPENAI_KEY"] = getpass("Enter your OpenAI API Key: ")

# %% [markdown]
# ### Create instance of extractor

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from llama_cloud_services import (
    LlamaExtract,
    EU_BASE_URL,
)

# Optionally, provide your project id, if not, it will use the 'Default' project
llama_extract = LlamaExtract(base_url=EU_BASE_URL)

print(EU_BASE_URL)
# Out:
# https://api.cloud.eu.llamaindex.ai

# %% [markdown]
# ### Define the data schema

# %%
from pydantic import BaseModel, Field


class ToyCatalog(BaseModel):
    """Product information from a toy catalog."""

    section_name: str = Field(
        description="The name of the toy section (e.g. Table Toys, Active Toys)."
    )
    product_code: str = Field(
        description="The unique product code for the toy (e.g., GA457)."
    )
    toy_name: str = Field(description="The name of the toy.")
    age_range: str = Field(
        description="The recommended age range for the toy (e.g., 6 +, 4 +).",
    )
    player_range: str = Field(
        description="The number of players the toy is designed for (e.g., 2, 2-4, 1-6).",
    )
    material: str = Field(
        description="The primary material(s) the toy is made of (e.g., wood, cardboard).",
    )
    description: str = Field(
        description="A brief description of the toy and its components and dimensions.",
    )

# %% [markdown]
# ---
# ### Testing - With ``extraction_target``: 'PER_TABLE_ROW'
# ---

# %%
from llama_cloud_services.extract import ExtractConfig, ExtractMode, ExtractTarget

result_per_tab_row = await llama_extract.aextract(
    data_schema=ToyCatalog,
    files="/home/daghbeji/ragragi/genAI_3D_CAD/llamaindex/data/tabs/Click-BS-Toys-Catalogue-2024.pdf",
    config=ExtractConfig(
        extraction_mode=ExtractMode.PREMIUM,
        extraction_target=ExtractTarget.PER_TABLE_ROW,
        parse_model="anthropic-sonnet-4.5",
    ),
)

# %%
result_per_tab_row.config.chunk_mode
# Out:
# <DocumentChunkMode.PAGE: 'PAGE'>

# %%
len(result_per_tab_row.data)
# Out:
# 159

# %%
result_per_tab_row.data
# Out:
# [{'section_name': 'Table Toys',
#   'product_code': 'GA457',
#   'toy_name': 'Dots and Boxes',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': 'base 17x17 cm; 50 border pieces 4x1,2x0,3 cm; 34 trees 2,6x1,4 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA456',
#   'toy_name': '3 In a Row',
#   'age_range': '8+',
#   'player_range': '2',
#   'material': 'wood, pine, cardboard',
#   'description': 'base 24x22,5x2,5 cm; 30 cards 5,5x5 cm; 6 chips'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA467',
#   'toy_name': 'Which Cow am i?',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood, beech',
#   'description': '2 cow bases 56x4x4,5 cm; 16 cards 4x5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA460',
#   'toy_name': 'Balance Bunnies',
#   'age_range': '4+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': '1 base 35x12x25 cm; 7 bunnies 7 foxes; 1 dice 3 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA462',
#   'toy_name': 'Color Combination Race',
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': 'base 6,5x6,5x15 cm, rings 5,5x5,5x0,5 mm; cardholder 6x6x2 cm, cards 5,5x5,5 cm; color cards Ø 15,5 cm - Ø 7 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA465',
#   'toy_name': 'Plop It',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood, elastic, cardboard',
#   'description': '2 ploppers 8x5 cm; 2 net holders Ø 5cm, length 55 cm; 6 cards 1,5x2,5 cm; 30 balls Ø 2,5 cm; 1 rope 120 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA466',
#   'toy_name': 'Whack a Shape',
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'wood',
#   'description': 'base 38,5x15,5 cm; 2 stands; 36 half balls; 4 hammers; 1 dice 2,5 cm; 4 cards'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA458',
#   'toy_name': 'Sling Puck | Table Hockey',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': 'double sides base 39x21x3 cm; 10 chips Ø 2,5 cm; 2 pushers 4x4x3 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA039',
#   'toy_name': 'DIY Birdhouse',
#   'age_range': '3+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': 'house 9x9x13 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA319',
#   'toy_name': 'Triangle Domino',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood',
#   'description': '35 triangles 10x10 x10 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA350',
#   'toy_name': "Crocs' Socks",
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'cardboard',
#   'description': '48 card 9x9 cm; 4 plungers Ø 6 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA347',
#   'toy_name': 'Match the Veggie',
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': '54 fish 6x4x2,6 cm; 54 cards 7,5x5,5 cm; 3 dice 3 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA370',
#   'toy_name': 'Stack Tower',
#   'age_range': '4+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': '28x28 cm; 12 cards; 42 blocks; 1 rope'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA346',
#   'toy_name': 'Puzzzle Beezzz',
#   'age_range': '8+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': 'puzzel 18x16 cm; 30 cards; 9 puzzle pieces'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA372',
#   'toy_name': 'Speed Bows',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': '64 bows; 40 cards'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA054',
#   'toy_name': 'Giant Playing Cards',
#   'age_range': '8+',
#   'player_range': '1-6',
#   'material': 'laminated, cardboard',
#   'description': '54 cards, 21x29 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA329',
#   'toy_name': 'Ice Dream Stacker',
#   'age_range': '4+',
#   'player_range': '1-2',
#   'material': 'wood, cardboard',
#   'description': '2 cups 6x6x2 cm, 22 pcs, 30 cards'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA320',
#   'toy_name': 'Find the Fish',
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': '54 fish 6x4x2,6 cm, 54 cards 7,5x5,5 cm, 3 dice 3 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA294',
#   'toy_name': 'Match Puzzle',
#   'age_range': '8+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': '24 matches 21x0,9 cm, 30 cards'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA349',
#   'toy_name': 'Frames',
#   'age_range': '8+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': '48 frames L 9x9x0,9 cm, M 4x4x2 cm, S 2,5x2,5x2,5 cm, 50 cards'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA348',
#   'toy_name': 'Feed the Crocodile',
#   'age_range': '4+',
#   'player_range': '2-3',
#   'material': 'wood',
#   'description': '1 crocodile 21,5x3 cm; 20 pcs, 1 stick, 1 fish, 3 large, 12 medium, 7 small'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA397',
#   'toy_name': 'Find the Cat!',
#   'age_range': '6+',
#   'player_range': '2-6',
#   'material': 'cardboard, wood',
#   'description': 'cats 14x12 cm; dice 3 cm; board Ø 60 cm; buttons 1,5 cm; chips 3,5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA351',
#   'toy_name': 'Mikado Melon',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood',
#   'description': '30 sticks 15 cm; melon Ø 90 mm; 1 dice'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA408',
#   'toy_name': 'Mystery Tower',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood, cardboard',
#   'description': '2 towers 21x7x7 cm; 12 big blocks Ø 5x 3,5 cm; 12 small blocks 3x3x2 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA439',
#   'toy_name': 'Giraffe Challenge',
#   'age_range': '4+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': 'board 22x16,5 cm; sand timer; card holder; 15 cards 12x6 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA371',
#   'toy_name': 'Memo Fish',
#   'age_range': '3+',
#   'player_range': '2',
#   'material': 'wood, cardboard',
#   'description': '16 fish; 4 cards 26x26 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA374',
#   'toy_name': 'Tock & Goose',
#   'age_range': '6+',
#   'player_range': '2-6',
#   'material': 'wood',
#   'description': '24 pawns; 2 dice; 2 card decks; 1 board Ø 45 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA373',
#   'toy_name': 'Domino Train',
#   'age_range': '3+',
#   'player_range': '2-4',
#   'material': 'wood',
#   'description': '28 train wagons 8,5x5x1,2 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA399',
#   'toy_name': 'Robot Friends',
#   'age_range': '3+',
#   'player_range': '1-4',
#   'material': 'cardboard',
#   'description': '32 pieces'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA403',
#   'toy_name': 'Dream House Lotto',
#   'age_range': '3+',
#   'player_range': '2-6',
#   'material': 'cardboard',
#   'description': '6 houses 24x14 cm, 36 chips Ø 5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA393',
#   'toy_name': 'Perfect Pair Memo',
#   'age_range': '5+',
#   'player_range': '2-6',
#   'material': 'cardboard',
#   'description': '48 cards 8x6,5x5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA406',
#   'toy_name': 'Stack the Dragon',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood, felt',
#   'description': '20 pieces, 4 swords 16 cm, 1 tower 13 cm, 4 dragon heads 5,5x3 cm, bodies, 13x5,5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA407',
#   'toy_name': 'Clock',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'wood, cardboard',
#   'description': 'clock 18,5x20 cm, chipholder 4,5x12 cm, 24 chips 4,5x3 cm, 6 cards Ø 6 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA402',
#   'toy_name': 'Spin & Match',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood',
#   'description': '40 pieces, 12 tokens, 2 spinners 6,5x5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA401',
#   'toy_name': 'Brain Race',
#   'age_range': '8+',
#   'player_range': '1-2',
#   'material': 'wood, PET',
#   'description': '12 strips 27x2,7x0,8 cm; 40 cards 11x8,5x0,12 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA434',
#   'toy_name': 'The Wiggle',
#   'age_range': '6+',
#   'player_range': '2-6',
#   'material': 'cardboard',
#   'description': '61 cards 8,7x6,2 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA433',
#   'toy_name': 'Nii No Fleh',
#   'age_range': '6+',
#   'player_range': '2-6',
#   'material': 'cardboard',
#   'description': '67 cards 5,5x8,5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA437',
#   'toy_name': 'Dinner Spinner',
#   'age_range': '6+',
#   'player_range': '2-6',
#   'material': 'wood, cardboard',
#   'description': '1 big spinner Ø 28x1 cm; 1 small spinner Ø 10x0,5 cm; 45 cards 7x5,5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA409',
#   'toy_name': "Shoot'm",
#   'age_range': '6+',
#   'player_range': '1-3',
#   'material': 'pine wood, acrylic, elastic',
#   'description': '5 targets 8x8,5 cm; gun 20x27x10 cm; 25 elastics'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA440',
#   'toy_name': 'Zigzag',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': 'Round base Ø 25 cm, 4 tweezers, 40 cards 7.7x5.5 cm, 27 balls Ø 20mm.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA436',
#   'toy_name': 'Tiddlywinks',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood, cotton',
#   'description': '2 hoops 220x280x7 mm, 19x130x5 mm; 1 base 120x60x7 mm; 4 big & 24 small chips.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA391',
#   'toy_name': 'Animal Chat',
#   'age_range': '3+',
#   'player_range': '3-10',
#   'material': 'cardboard',
#   'description': '10x7.2 cm.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA432',
#   'toy_name': "Elephant's Bluff",
#   'age_range': '8+',
#   'player_range': '3-6',
#   'material': 'cardboard, wood',
#   'description': 'A dice game about bluff, who can you trust? Cup Ø 10.5x8 cm, 3 dices 3 cm, 6 elephants 2.5x0.5 cm, 6 cardboard strips 15.4 cm.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA451',
#   'toy_name': 'Square Puzzle',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': '9 bloks 15x15x0,8 cm; 15 cards 18x18 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA452',
#   'toy_name': "Panda's Puzzle",
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': 'board 13,5x13,5 cm; panda 4,5x4,5x8,5 cm; 7 pieces; 10 cards with front and back print'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA438',
#   'toy_name': 'Geoboard',
#   'age_range': '4+',
#   'player_range': '1',
#   'material': 'wood, cardboard, elastic',
#   'description': 'board 18x18x1,5 cm; 20 cards 9x9 cm; 2 eyes, Ø 2,5; 48 elastics (24 big +24 small)'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA449',
#   'toy_name': 'Shape Puzzle',
#   'age_range': '8+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': '5 pieces ca 9x4,5x0,5 cm; 20 cards 8x8 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA471',
#   'toy_name': 'Stilts',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': '2 stilts length 110 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA353',
#   'toy_name': 'Bow & Arrow - Apple',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': '1 bow 45x12x1,5 cm, 3 arrows 26x2,5 cm, 3 apples 13x13x1,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA475',
#   'toy_name': 'Bow & Arrow',
#   'age_range': '5+',
#   'player_range': '1',
#   'material': 'wood, felt, fabric',
#   'description': '1 bow 40x13 cm, 3 arrow 26,5 cm, 1 target sheet 26x29,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA473',
#   'toy_name': 'Catch Game',
#   'age_range': '4+',
#   'player_range': '2',
#   'material': 'wood, velcro',
#   'description': 'front velcro, back wood Ø 19,2 cm, 1 soft fabric ball Ø 7,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA476',
#   'toy_name': 'Lacrosse Kit',
#   'age_range': '8+',
#   'player_range': '2',
#   'material': 'wheat straw plastic, neoprene ball',
#   'description': '2 rackets, 41x4 cm, 1 ball Ø 5,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA344',
#   'toy_name': 'Elastic Jump',
#   'age_range': '4+',
#   'player_range': '1-6',
#   'material': 'elastic',
#   'description': 'length material 3 meter, width 2 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA130',
#   'toy_name': 'Walking Ski',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': 'for 2 persons, size 90x8,5x2 cm, 34 trees 2,6x1,4 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA468',
#   'toy_name': 'Padel Rackets',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': '2 rackets, 42x21 cm, ball Ø 5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA230',
#   'toy_name': 'Large Jumping Rope',
#   'age_range': '6+',
#   'player_range': '3-10',
#   'material': 'wood, cotton',
#   'description': 'rope length 5 m'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA478',
#   'toy_name': 'Catch the Fruit',
#   'age_range': '8+',
#   'player_range': '1-6',
#   'material': 'wood',
#   'description': '27 fruit frisbees Ø 9 cm; 4 catching sticks 28x Ø 10 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA380',
#   'toy_name': 'Jumping Rope - Turquoise',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, rope',
#   'description': 'rope length 2 meter'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA379',
#   'toy_name': 'Jumping Rope - Pink',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, rope',
#   'description': 'rope length 2 meter'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA422',
#   'toy_name': 'Blow Darts',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, paper',
#   'description': 'blowgun 50 cm; 3 targets Ø 5 to 8 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA382',
#   'toy_name': 'Ring Toss - Birds',
#   'age_range': '4+',
#   'player_range': '1-3',
#   'material': 'wood, sisal',
#   'description': '1x Ø 10 cm; 6 chips'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA231',
#   'toy_name': 'Tug of War',
#   'age_range': '6+',
#   'player_range': '2-12',
#   'material': 'hemp rope, pine wood',
#   'description': '10 meter length, Ø 2 cm; incl. centerline and pegs'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA418',
#   'toy_name': 'Balance Surfboard',
#   'age_range': '4+',
#   'player_range': '1',
#   'material': 'wood, wood',
#   'description': 'board 50x32x4 cm; 2 big balls Ø 3,5 cm; 3 small balls Ø 2 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA429',
#   'toy_name': 'Ninja Launcher',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'wood, cork, fabric',
#   'description': '1 launcher 65x8x5 cm; 6 ninjas Ø 2,8x4,5 cm; racket 29x11,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA354',
#   'toy_name': 'Dance Ribbon',
#   'age_range': '3+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': 'stick 32x1x1 cm, ribbon 30x4 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA479',
#   'toy_name': 'Twirl Stick',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, cork, fabric ribbons',
#   'description': 'stick 45,5 cm, 2 (attached to stick) balls Ø 4 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA411',
#   'toy_name': 'Run & Match',
#   'age_range': '4+',
#   'player_range': '2-6',
#   'material': 'pine, cotton, fabric',
#   'description': 'mats 37x34 cm, 8 sticks Ø 2,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA480',
#   'toy_name': 'Poi Sling',
#   'age_range': '4+',
#   'player_range': '1',
#   'material': 'wood, cork, fabric ribbons',
#   'description': 'handle 21,5 cm, rope 41 cm, ball Ø 6 cm, 8 ribbons 140 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA427',
#   'toy_name': 'Flying de Boules',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood, fabric',
#   'description': '6 parachutes, 1 island 10x9x0,5 cm, rope 1 m'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA381',
#   'toy_name': 'Bean Bag Bunnies',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'wood, cotton',
#   'description': 'height bunnies 12 to 16 cm, 3 bags'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA477',
#   'toy_name': 'Bounce Rackets',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'bamboo, fabric',
#   'description': 'set rackets Ø 29 cm; 1 rubber ball Ø 9.5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA377',
#   'toy_name': 'Elastic Tennis',
#   'age_range': '8+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': '2 bats, 35x14.5x0.8 cm; base 15x10x5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA333',
#   'toy_name': 'Wooden Walking Bobbins',
#   'age_range': '3+',
#   'player_range': '1',
#   'material': 'compressed wood, cotton',
#   'description': '12x12x5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA305',
#   'toy_name': 'Diabolo',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, rubber',
#   'description': 'Ø 10 cm; sticks 38 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA396',
#   'toy_name': 'Ankle Swing',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, rope',
#   'description': 'rope 75 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA394',
#   'toy_name': 'Swing & Loop Racket',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': 'racket 29x41x4 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA419',
#   'toy_name': 'Wheel of Action',
#   'age_range': '3+',
#   'player_range': '2-20',
#   'material': 'wood',
#   'description': '1 wheel and 1 double side printed plate; 44x40x4 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA387',
#   'toy_name': 'Hurdles & Limbo',
#   'age_range': '6+',
#   'player_range': '1-10',
#   'material': 'plastic',
#   'description': 'max. height hurdle 56 cm; max. height limbo 102 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA126',
#   'toy_name': 'Jumping Cow',
#   'age_range': '3+',
#   'player_range': '1',
#   'material': 'plastic',
#   'description': '50 kg max; sitting height 27 cm; length 50 cm; incl. pump'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA148',
#   'toy_name': 'Bowling - Red & White',
#   'age_range': '4+',
#   'player_range': '1-3',
#   'material': 'birch wood',
#   'description': '10 pins 18 cm; 2 balls'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA149',
#   'toy_name': 'Skittles jr.',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'birch wood',
#   'description': '6 skittles 18 cm; 1 ball'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA450',
#   'toy_name': 'Birds in Action',
#   'age_range': '4+',
#   'player_range': '2-10',
#   'material': 'wood',
#   'description': '4 dice, big 7 cm; letter 4 cm; chips 4.5x4.5x1.2 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA423',
#   'toy_name': 'Pulley Set',
#   'age_range': '3+',
#   'player_range': '2',
#   'material': 'metal, fabric',
#   'description': '1 bucket, 1 bag; 2 carabiners; 2 s-shaped hooks, rope'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA321',
#   'toy_name': 'Belly Catch Set',
#   'age_range': '3+',
#   'player_range': '2-4',
#   'material': 'fabric, velcro',
#   'description': 'includes 4 soft balls'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA204',
#   'toy_name': 'Active Coordination Game',
#   'age_range': '6+',
#   'player_range': '2-8',
#   'material': 'wood',
#   'description': 'Cooperate and bring the ball to their height! 35x35x4 cm; 3 challenges; 3 balls, 8 handles'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA442',
#   'toy_name': 'XXL Park Darts',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'fabric, metal, wood, felt',
#   'description': '1 dart field Ø 1 m; 3 darts; 4 metal pegs'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA412',
#   'toy_name': 'Juggling Balls',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'neoprene, with recycled filling',
#   'description': '3 balls Ø 6 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA386',
#   'toy_name': 'Table Tennis Net',
#   'age_range': '8+',
#   'player_range': '2',
#   'material': 'plastic',
#   'description': 'folded 20x15x5.5 cm; 1 net; max table width 170 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA428',
#   'toy_name': 'Feed the Penguin',
#   'age_range': '3+',
#   'player_range': '1-4',
#   'material': 'fabric, wood, felt and plastic pallets',
#   'description': 'cloth 80x150 cm; 3 fish 12x8 cm; 4x rope 1.25 m; 2 beams'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA472',
#   'toy_name': 'Kendama Ice Cream',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': 'cone with ball; length 12.5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA299',
#   'toy_name': 'Kendama',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': 'with rubber coating; 7x18x6 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA414',
#   'toy_name': 'Crab Fishing',
#   'age_range': '8+',
#   'player_range': '1-2',
#   'material': 'wood',
#   'description': '2 fishing rods, 10 crabs 15x8,5x1,8 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA400',
#   'toy_name': 'Color Targets',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': '2 bows 16x9,5 cm, 2 pucks Ø 6 cm, 15 targets 7x6 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA337',
#   'toy_name': 'Indoor Curling',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'birch wood',
#   'description': '8 stones 10x10x2,5 cm, 4 applicators 6x6x5cm, 1 puck 6x6x1,2cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA355',
#   'toy_name': 'Bowling - Forest Friends',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'wood',
#   'description': '6 pieces approx. 17x9x1,8 cm, 1 ball'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA446',
#   'toy_name': 'The Outdoor Arrow',
#   'age_range': '4+',
#   'player_range': '2-24',
#   'material': 'wood',
#   'description': 'arrow 35x9x4 cm; 24 chips Ø 6x0,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA448',
#   'toy_name': 'Color Wheel',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'wood',
#   'description': 'spinner Ø 18x0,5 cm; rope 60 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA441',
#   'toy_name': 'Roll & Stop',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'fabric, cork, metal',
#   'description': '1 sheet 50x200 cm; 3 balls Ø 6,5 cm; 4 pegs'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA424',
#   'toy_name': 'Red Light Green Light',
#   'age_range': '8+',
#   'player_range': '3-10',
#   'material': 'wood, fabric',
#   'description': '1 finish line; 25 pyramids 5x5x2,5 cm; 1 bag'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA426',
#   'toy_name': 'Flag a Tag',
#   'age_range': '3+',
#   'player_range': '2-4',
#   'material': 'felt, velcro',
#   'description': '4 belts 80x4 cm; 16 tales 23x3,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA430',
#   'toy_name': 'Click & Play - Doorway Ball',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood, elastic, foam',
#   'description': 'door hanger 21x14x1.7 cm, ball Ø 9 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA416',
#   'toy_name': 'Wobbly Lilly Path',
#   'age_range': '3+',
#   'player_range': '1-4',
#   'material': 'wood',
#   'description': 'frogs 4.5x4 cm, lilypad 17x16x3 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA431',
#   'toy_name': 'Reflex Boxing Ball',
#   'age_range': '8+',
#   'player_range': '1-2',
#   'material': 'fabric, elastic, foam',
#   'description': '1 headband 65 cm, ball Ø 9 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA425',
#   'toy_name': 'Bullet Ball',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': 'rope 2x 2 m'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA413',
#   'toy_name': 'Gecko Racket',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood, velcro',
#   'description': '1 racket 29x19x0.8 cm, 8 flies'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA410',
#   'toy_name': 'Who is the Thief?',
#   'age_range': '4+',
#   'player_range': '2-10',
#   'material': 'wood, cotton',
#   'description': '11 pieces approx 12x6x0,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA445',
#   'toy_name': 'Lighthouse Relay',
#   'age_range': '6+',
#   'player_range': '2-8',
#   'material': 'wood',
#   'description': '2 lighthouse 12,5x9x9 cm, 2 balance boards 27x13x0,8 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA443',
#   'toy_name': 'Balancing Bob',
#   'age_range': '8+',
#   'player_range': '2-4',
#   'material': 'wood, silicon, metal',
#   'description': 'bob 16x7x2,5 cm, pole Ø 2,2x110 cm, 3 discs 6x6x1,2 cm, platform Ø 15x1 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA447',
#   'toy_name': 'Soccer Tins',
#   'age_range': '4+',
#   'player_range': '1-2',
#   'material': 'metal, plastic',
#   'description': '6 tins 11x11x10 cm, football Ø 10 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA444',
#   'toy_name': 'Squirrel Parachutes',
#   'age_range': '4+',
#   'player_range': '2-20',
#   'material': 'polyester, felt',
#   'description': '5 parachutes Ø 100 cm, 5 flying bean bag squirrels 13x7x2 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA264',
#   'toy_name': 'Moves!',
#   'age_range': '6+',
#   'player_range': '2-8',
#   'material': 'wood',
#   'description': '18 chips Ø 8 cm. Remember the sequence.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA392',
#   'toy_name': 'Bugs - Active Search Game',
#   'age_range': '3+',
#   'player_range': '2-12',
#   'material': 'wood',
#   'description': '18 chips Ø 8 cm. 2 dice 4 cm.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA454',
#   'toy_name': 'Ducks in a Row',
#   'age_range': '3+',
#   'player_range': '1-4',
#   'material': 'wood',
#   'description': '1 base with 4 ducks 6x10x40 cm. 3 bean bags.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA404',
#   'toy_name': 'Treasure Hunt',
#   'age_range': '3+',
#   'player_range': '2-8',
#   'material': 'cardboard',
#   'description': '101 cards 8x8 cm. 22 envelopes 10x9 cm.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA481',
#   'toy_name': 'Run to the Color',
#   'age_range': '6+',
#   'player_range': '3-12',
#   'material': 'wood, cotton',
#   'description': '6 ropes 1,5 m (total length of ropes 9 m); 15 coloured chips 5x4,5 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA364',
#   'toy_name': 'Party Kit',
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': '',
#   'description': '4 jumping bags 70x50 cm; 4 spoons; 4 eggs; 10 cups; 4 throwing bags; 4 pegs; start and finish line'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA332',
#   'toy_name': 'Egg Relay',
#   'age_range': '4+',
#   'player_range': '1-4',
#   'material': 'plastic',
#   'description': '4 spoons; 4 eggs; 4 inner eggs'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA133',
#   'toy_name': 'Parachute',
#   'age_range': '4+',
#   'player_range': '4-12',
#   'material': 'fabric',
#   'description': 'Ø 3 m; 12 handles; 24 plastic balls'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA301',
#   'toy_name': 'Catching Tails',
#   'age_range': '3+',
#   'player_range': '1-4',
#   'material': 'felt',
#   'description': '6 clip-on tails; size 30x2,5 cm'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA196',
#   'toy_name': 'Big Bubbles',
#   'age_range': '3+',
#   'player_range': '1',
#   'material': 'pine, cotton',
#   'description': 'poles 65 cm'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA378',
#   'toy_name': 'Diving Bow',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'neoprene, sand filling',
#   'description': 'tube 2 m'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA455',
#   'toy_name': 'Water Spraying Whale',
#   'age_range': '3+',
#   'player_range': '1-8',
#   'material': 'wheat straw, silicon',
#   'description': '22,5x14x11 cm tubes 29 cm Ø 0,5 mm'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA303',
#   'toy_name': 'Bounce Tennis',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'neoprene',
#   'description': '2 rackets 57x32 cm fluffy ball'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA388',
#   'toy_name': 'Diving Animals',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'neoprene, sand filling',
#   'description': 'Set includes three diving animal toys (a dark dolphin/whale, a spotted pufferfish, and a red octopus). Each toy approx. Ø ca. 21 cm.'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA453',
#   'toy_name': 'Aquascope',
#   'age_range': '3+',
#   'player_range': '1',
#   'material': 'pressed wood',
#   'description': 'Aquascope for underwater viewing, dimensions 20x6x10 cm. Set includes a yellow cylindrical aquascope with viewing window and a blue whale-shaped toy.'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA173',
#   'toy_name': 'Diving Animals',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'neoprene, sand filling',
#   'description': 'Set includes three diving animal toys (a yellow seahorse, a pink starfish, and a blue turtle). Each toy approx. Ø ca. 14 cm.'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA302',
#   'toy_name': 'Diving Memo',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'neoprene, sand filling',
#   'description': 'Underwater-themed memo game. Includes 12 pcs, each circular piece Ø 10 cm, with various underwater creature designs.'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA014',
#   'toy_name': 'Mega Mikado',
#   'age_range': '8+',
#   'player_range': '2-6',
#   'material': 'bamboo',
#   'description': 'length 90 cm, Ø 0,7 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA093',
#   'toy_name': 'Tin Throwing - Red',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'metal',
#   'description': '10 tins Ø 6 cm height 10 cm, incl. 3 throwing bags'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA131',
#   'toy_name': 'Tin Throwing - Blue',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'metal',
#   'description': '10 tins Ø 6 cm height 10 cm, incl. 3 throwing bags'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA420',
#   'toy_name': 'Giant Ball',
#   'age_range': '3+',
#   'player_range': '1-8',
#   'material': 'fabric, inflatable core',
#   'description': 'pump not included, Ø 50 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA362',
#   'toy_name': 'Tin Throwing - Wildlife',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'metal',
#   'description': '6 tins Ø 6 cm height 10 cm, incl. 3 throwing bags'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA463',
#   'toy_name': 'Bowling',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'wood, cork',
#   'description': '10 pins 18x6x2 cm, 2 balls Ø 5 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA123',
#   'toy_name': 'Kubb - Official size',
#   'age_range': '8+',
#   'player_range': '2-6',
#   'material': 'pine',
#   'description': '8x kubbs 7x7x15 cm, 1x king 7x7x30 cm, 6x throwing sticks 30 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA122',
#   'toy_name': 'Crocket Jr.',
#   'age_range': '3+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': '2 mallets 42 cm, 2 balls, 6 dogs height approx 20 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA474',
#   'toy_name': 'Golf Set',
#   'age_range': '4+',
#   'player_range': '1-2',
#   'material': 'wood',
#   'description': '2 golf sticks 57x8 cm, 2 balls Ø 3,5 cm, 1 hole 10x8x12,5 cm, 3 bows 16x11 cm, 1 bridge 20x8 cm, 2 obstacles 8x10 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA128',
#   'toy_name': 'Finnish Throwing Game',
#   'age_range': '8+',
#   'player_range': '2-4',
#   'material': 'pine',
#   'description': 'height 15 cm, diameter 5,5 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA417',
#   'toy_name': 'Scoreboard',
#   'age_range': '3+',
#   'player_range': '',
#   'material': 'wood',
#   'description': '30x15x11 cm; 2 chalks'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA279',
#   'toy_name': 'Giant Four in a Row',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': '57x39 cm; 42 chips'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA277',
#   'toy_name': 'Giant Tumble Tower',
#   'age_range': '4+',
#   'player_range': '1-10',
#   'material': 'wood',
#   'description': 'incl. 60 blocks and 1 dice; block size 20x4.5x2.5 cm; max hight 1 m'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA242',
#   'toy_name': 'Giant Draughts',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': 'non woven field 85x85 cm; 40 chips Ø 7 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA263',
#   'toy_name': 'Giant Tic Tac Toe',
#   'age_range': '4+',
#   'player_range': '2',
#   'material': 'wood, fabric',
#   'description': 'field size 70x70 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA241',
#   'toy_name': 'Jeu de Boules',
#   'age_range': '6+',
#   'player_range': '2-3',
#   'material': 'wood',
#   'description': '6 boules Ø 6,5 cm, 1 target ball'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA278',
#   'toy_name': 'Giant Domino',
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'wood',
#   'description': '28 pieces 15x7,5x1,5 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA383',
#   'toy_name': 'Crocket - Rainbow',
#   'age_range': '4+',
#   'player_range': '1-2',
#   'material': 'wood',
#   'description': '3 rainbow ports 21x15x8 cm, 2 clubs 45 cm, 2 balls'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA415',
#   'toy_name': 'Corn Hole',
#   'age_range': '8+',
#   'player_range': '2-6',
#   'material': 'wood, cotton',
#   'description': '2 boards 30x60x0,9 cm, 8 bags 8x8x8 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA202',
#   'toy_name': 'Shooting Game',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'birch, elastic',
#   'description': 'target board 24 x 7 x 16 cm, 12 elastics'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA470',
#   'toy_name': 'Ring Toss - Round',
#   'age_range': '4+',
#   'player_range': '1-3',
#   'material': 'wood, cotton',
#   'description': 'base 1 Ø 25 cm x 16 cm, base 2 Ø 7cm x 16 cm, 5 rings Ø 12 cm, 5 sticks'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA145',
#   'toy_name': 'Ring Toss',
#   'age_range': '6+',
#   'player_range': '1-3',
#   'material': 'pine',
#   'description': '5 rings, 50x50x10 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA366',
#   'toy_name': 'Hook Toss',
#   'age_range': '6+',
#   'player_range': '1-4',
#   'material': 'wood',
#   'description': '30x30x2 cm, 12 rings'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA162',
#   'toy_name': 'Ladder Game',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood',
#   'description': 'incl. 6 balls, 75x55 cm'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA050',
#   'toy_name': 'Disc Darts',
#   'age_range': '6+',
#   'player_range': '1-3',
#   'material': 'fabric',
#   'description': 'Ø 2 m, 3 disks, 4 pegs'},
#  {'section_name': 'Table Toys',
#   'product_code': 'BS',
#   'toy_name': 'Branded Cube and Extendable Shelf Display',
#   'age_range': '',
#   'player_range': '',
#   'material': 'kraft cardboard',
#   'description': 'Cube and extendable shelf display made of kraft cardboard. The display is 37 cm high and extends from 75 cm to a maximum position of 135 cm in width.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA457',
#   'toy_name': 'Dots and Boxes',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA462',
#   'toy_name': 'Color Combination Race',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA467',
#   'toy_name': 'Which Cow am i?',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA456',
#   'toy_name': '3 in a Row',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA460',
#   'toy_name': 'Balance Bunnies',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA458',
#   'toy_name': 'Sling Puck | Table Hockey',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''}]

# %% [markdown]
# ---
# ### Testing - With ``extraction_target``: 'PER_DOC'
# ---

# %%
result_per_doc = await llama_extract.aextract(
    data_schema=ToyCatalog,
    files="/home/daghbeji/ragragi/genAI_3D_CAD/llamaindex/data/tabs/Click-BS-Toys-Catalogue-2024.pdf",
    config=ExtractConfig(
        extraction_mode=ExtractMode.PREMIUM,
        extraction_target=ExtractTarget.PER_DOC,
        parse_model="anthropic-sonnet-4.5",
    ),
)

# %%
len(result_per_doc.data)
# Out:
# 7

# %%
result_per_doc.data
# Out:
# {'section_name': 'Table Toys',
#  'product_code': 'GA457',
#  'toy_name': 'Dots and Boxes',
#  'age_range': '6+',
#  'player_range': '2',
#  'material': 'wood',
#  'description': 'Base 17x17 cm, 50 border pieces 4x1,2x0,3 cm, 34 trees 2,6x1,4 cm. A tabletop game for 2 players, made of wood.'}

# %% [markdown]
# ---
# ### Testing - With ``extraction_target``: 'PER_PAGE'
# ---

# %%
result_per_page = await llama_extract.aextract(
    data_schema=ToyCatalog,
    files="/home/daghbeji/ragragi/genAI_3D_CAD/llamaindex/data/tabs/Click-BS-Toys-Catalogue-2024.pdf",
    config=ExtractConfig(
        extraction_mode=ExtractMode.PREMIUM,
        extraction_target=ExtractTarget.PER_PAGE,
        parse_model="anthropic-sonnet-4.5",
    ),
)

# %%
len(result_per_page.data)
# Out:
# 39

# %%
result_per_page.data
# Out:
# [{'section_name': '',
#   'product_code': '',
#   'toy_name': '',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''},
#  {'section_name': '',
#   'product_code': '',
#   'toy_name': '',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': 'This page is an introduction to the BS Toys catalog. It does not provide explicit product information or describe specific toys according to the schema. It highlights the catalog contents, company mission, rebranding, and the developmental benefits symbols used throughout the catalog.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA457',
#   'toy_name': 'Dots and Boxes',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood',
#   'description': 'Base 17x17 cm, 50 border pieces 4x1.2x0.3 cm, 34 trees 2.6x1.4 cm.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA465',
#   'toy_name': 'Plop It',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood, elastic, cardboard',
#   'description': 'Catch the right balls and put them in the net! Includes: 2 ploppers (8x5 cm), 2 net holders (Ø 5 cm, length 55 cm), 6 cards (1.5x2.5 cm), 30 balls (Ø 2.5 cm), 1 rope (120 cm).'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA350',
#   'toy_name': "Crocs' Socks",
#   'age_range': '4+',
#   'player_range': '2-4',
#   'material': 'cardboard',
#   'description': '48 card 9x9 cm, 4 plungers Ø 6 cm. Train your spatial awareness.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA054',
#   'toy_name': 'Giant Playing Cards',
#   'age_range': '8+',
#   'player_range': '1-6',
#   'material': 'laminated, cardboard',
#   'description': '54 cards, 21x29 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA348',
#   'toy_name': 'Feed the Crocodile',
#   'age_range': '4+',
#   'player_range': '2-3',
#   'material': 'wood',
#   'description': 'Wooden crocodile toy (21.5 x 3 cm) with 20 pieces, 1 stick, 1 fish. Includes 3 large, 12 medium, and 7 small pieces.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA439',
#   'toy_name': 'Giraffe Challenge',
#   'age_range': '4+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': 'Board 22x16,5 cm; includes a sand timer, card holder, and 15 cards (12x6 cm).'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA403',
#   'toy_name': 'Dream House Lotto',
#   'age_range': '3+',
#   'player_range': '2-6',
#   'material': 'cardboard',
#   'description': '6 houses 24x14 cm, 36 chips Ø 5 cm'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA401',
#   'toy_name': 'Brain Race',
#   'age_range': '8+',
#   'player_range': '1-2',
#   'material': 'wood, PET',
#   'description': '12 strips (27x2.7x0.8 cm), 40 cards (11x8.5x0.12 cm).'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA440',
#   'toy_name': 'Zigzag',
#   'age_range': '6+',
#   'player_range': '2-4',
#   'material': 'wood, cardboard',
#   'description': 'Round base Ø 25 cm, 4 tweezers, 40 cards 7.7x5.5 cm, 27 balls Ø 20mm.'},
#  {'section_name': 'Table Toys',
#   'product_code': 'GA451',
#   'toy_name': 'Square Puzzle',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, cardboard',
#   'description': '9 bloks 15x15x0,8 cm 15 cards 18x18 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA471',
#   'toy_name': 'Stilts',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': '2 stilts, length 110 cm.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA344',
#   'toy_name': 'Elastic Jump',
#   'age_range': '4+',
#   'player_range': '1-6',
#   'material': 'elastic',
#   'description': 'Elastic jump band made of elastic material, 3 meters in length and 2 cm wide.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA230',
#   'toy_name': 'Large Jumping Rope',
#   'age_range': '6+',
#   'player_range': '3-10',
#   'material': 'wood, cotton',
#   'description': 'Jumping rope with wooden handles. Rope length 5 m.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA422',
#   'toy_name': 'Blow Darts',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood, paper',
#   'description': 'Blowgun 50 cm, 3 targets Ø 5 to 8 cm.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA354',
#   'toy_name': 'Dance Ribbon',
#   'age_range': '3+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': 'Stick 32x1x1 cm; ribbon 30x4 cm.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA477',
#   'toy_name': 'Bounce Rackets',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'bamboo, fabric',
#   'description': 'Set rackets Ø 29 cm, 1 rubber ball Ø 9.5 cm.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA394',
#   'toy_name': 'Swing & Loop Racket',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'wood',
#   'description': 'Wooden racket measuring 29x41x4 cm. Recommended for 1 player aged 6 and up.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA450',
#   'toy_name': 'Birds in Action',
#   'age_range': '4+',
#   'player_range': '2-10',
#   'material': 'wood',
#   'description': 'Includes 4 dice (big, 7 cm), letter (4 cm), chips (4.5x4.5x1.2 cm).'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA412',
#   'toy_name': 'Juggling Balls',
#   'age_range': '6+',
#   'player_range': '1',
#   'material': 'neoprene, with recycled filling',
#   'description': 'Set of 3 juggling balls, each with a diameter of 6 cm. Balls come in blue, turquoise, and yellow colors with "B" logos.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA414',
#   'toy_name': 'Crab Fishing',
#   'age_range': '8+',
#   'player_range': '1-2',
#   'material': 'wood',
#   'description': '2 fishing rods, 10 crabs 15x8.5x1.8 cm'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA446',
#   'toy_name': 'The Outdoor Arrow',
#   'age_range': '4+',
#   'player_range': '2-24',
#   'material': 'wood',
#   'description': 'The Outdoor Arrow game consists of a striped arrow-shaped pointer (35x9x4 cm) and 24 circular chips (Ø 6x0.5 cm) in various colors with white bases. Designed for outdoor play.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA430',
#   'toy_name': 'Click & Play - Doorway Ball',
#   'age_range': '6+',
#   'player_range': '2',
#   'material': 'wood, elastic, foam',
#   'description': 'A doorway ball game for 2 players, consisting of a door hanger (21x14x1.7 cm) and a ball (Ø 9 cm).'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA410',
#   'toy_name': 'Who is the Thief?',
#   'age_range': '4+',
#   'player_range': '2-10',
#   'material': 'wood, cotton',
#   'description': '11 pieces approx 12x6x0.5 cm. A game set made of wood and cotton with treasure-themed pieces.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA264',
#   'toy_name': 'Moves!',
#   'age_range': '6+',
#   'player_range': '2-8',
#   'material': 'wood',
#   'description': '18 chips Ø 8 cm. Remember the sequence.'},
#  {'section_name': 'Active Toys',
#   'product_code': 'GA481',
#   'toy_name': 'Run to the Color',
#   'age_range': '6+',
#   'player_range': '3-12',
#   'material': 'wood, cotton',
#   'description': 'Includes 6 ropes of 1.5 m each (total length 9 m) and 15 coloured chips (5x4.5 cm).'},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA455',
#   'toy_name': 'Water Spraying Whale',
#   'age_range': '3+',
#   'player_range': '1-8',
#   'material': 'wheat straw, silicon',
#   'description': "A blue whale-shaped water spraying toy measuring 22.5x14x11 cm, includes tubes (length 29 cm, diameter 0.5 mm). The whale's body is made of wheat straw. NEW! in open kraft packaging."},
#  {'section_name': 'Water Toys',
#   'product_code': 'GA388',
#   'toy_name': 'Diving Animals',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'neoprene, sand filling',
#   'description': 'Set of three diving animal toys (dark dolphin/whale, spotted pufferfish, red octopus), approximately 21 cm in diameter.'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA014',
#   'toy_name': 'Mega Mikado',
#   'age_range': '8+',
#   'player_range': '2-6',
#   'material': 'bamboo',
#   'description': 'Length 90 cm, diameter 0.7 cm. A large version of the classic Mikado game using bamboo sticks.'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA463',
#   'toy_name': 'Bowling',
#   'age_range': '3+',
#   'player_range': '1-3',
#   'material': 'wood, cork',
#   'description': '10 pins 18x6x2 cm, 2 balls Ø 5 cm.'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA417',
#   'toy_name': 'Scoreboard',
#   'age_range': '3+',
#   'player_range': '',
#   'material': 'wood',
#   'description': 'Wooden scoreboard, 30x15x11 cm, includes 2 chalks.'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA241',
#   'toy_name': 'Jeu de Boules',
#   'age_range': '6+',
#   'player_range': '2-3',
#   'material': 'wood',
#   'description': '6 wooden boules (Ø 6,5 cm), 1 target ball.'},
#  {'section_name': 'Classic Toys',
#   'product_code': 'GA202',
#   'toy_name': 'Shooting Game',
#   'age_range': '6+',
#   'player_range': '1-2',
#   'material': 'birch, elastic',
#   'description': 'A shooting game made of birch and elastic. Includes a target board measuring 24 x 7 x 16 cm and 12 elastics.'},
#  {'section_name': '',
#   'product_code': '',
#   'toy_name': '',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': ''},
#  {'section_name': 'Point of Sale',
#   'product_code': '',
#   'toy_name': 'BS branded cube and extendable shelf display',
#   'age_range': '',
#   'player_range': '',
#   'material': 'kraft cardboard',
#   'description': 'A point of sale display made of kraft cardboard. The display is 37 cm high and extends from 75 cm to a maximum width of 135 cm.'},
#  {'section_name': 'Table Toys',
#   'product_code': '',
#   'toy_name': 'wooden peg board game',
#   'age_range': '',
#   'player_range': '',
#   'material': 'wood',
#   'description': 'A wooden peg board game featuring circular wooden pieces in various colors (red, yellow, teal, purple, green), each set into natural wood rings and arranged in a grid pattern. Includes a wooden mallet positioned at the top right of the board.'},
#  {'section_name': '',
#   'product_code': 'GA457',
#   'toy_name': 'Dots and Boxes',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': 'No additional information is provided except the product code and name from the index.'},
#  {'section_name': '',
#   'product_code': '',
#   'toy_name': '',
#   'age_range': '',
#   'player_range': '',
#   'material': '',
#   'description': "This page contains company contact information and general promotional material for BS Toys, including images of their products and their slogan 'play. move, learn!'. No specific toy data, product codes, or descriptions are provided."}]

# %% [markdown]
# ## Result
#
# -``PER_TABLE_ROW``: All Toys (159) were extracted<br>
# -``PER_DOC``: Only 7 Toys were extracted<br>
# -``PER_PAGE``: Only 39 Toys were extracted
